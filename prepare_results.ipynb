# %%
from pathlib import Path
import pandas as pd
from IPython.display import display

# %%
dfs = []
for file in Path(".").glob("*_cis.csv"):
    df = pd.read_csv(file)
    dfs.append(df)
    display(df.head(n=1))
# Out:
#    model_name  ...  ci95_mean_learning_time_by_epoch_sec_lo
# 0          18  ...                     [160.28751672073577]
#
# [1 rows x 23 columns]
#    model_name  ...  ci95_mean_learning_time_by_epoch_sec_lo
# 0          18  ...                     [159.08157164750114]
#
# [1 rows x 23 columns]
#    model_name  ...  ci95_mean_learning_time_by_epoch_sec_lo
# 0          18  ...                      [158.3164649589064]
#
# [1 rows x 23 columns]
#    model_name  ...  ci95_mean_learning_time_by_epoch_sec_lo
# 0          18  ...                      [153.4591685084551]
#
# [1 rows x 23 columns]
#    model_name  ...  ci95_mean_learning_time_by_epoch_sec_lo
# 0          18  ...                      [150.0008797148042]
#
# [1 rows x 23 columns]
#    model_name  ...  ci95_mean_learning_time_by_epoch_sec_lo
# 0          18  ...                     [153.06287597606584]
#
# [1 rows x 23 columns]

# %%
pd.concat(dfs).groupby("slaves_num").mean()
# Out:
# /tmp/ipykernel_2270/224349195.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.concat(dfs).groupby("slaves_num").mean()
#             model_name  epochs  ...      loss  mean_learning_time_by_epoch_sec
# slaves_num                      ...
# 1                 18.0    10.0  ...  0.063011                       159.876096
# 5                 18.0    10.0  ...  0.051029                       155.991033
# 16                18.0    10.0  ...  0.040973                       151.823100
#
# [3 rows x 8 columns]
